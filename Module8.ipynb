# %% [markdown]
# **TRACE OF AN INFINITE SQUARE MATRIX**
#
# Property (Trace of a Matrix)
#
# The trace of a square matrix is the sum of diagonal elements:
#
# Tr
# (
# 𝐴
# )
# =
# ∑
# 𝑎
# 𝑖
# 𝑖
# Tr(A)=∑a
# ii
# 	​

# %% [markdown]
# Observation (Key Insight)
#
# Diagonal elements follow the pattern:
#
# 1,1/2, 1/4, 1/8 ...
#
# This is an infinite geometric series with:
#
# First term
# 𝑎
# =
# a=1
# =
# Common ratio
# 𝑟= 1/2
# 	​
#
#
# Mathematical Solution
#
# Sum of infinite geometric series:
#
# 𝑆
# =
# 𝑎
# 1
# −
# 𝑟
# S=
# 1−r
# a
# 	​
#
# Tr
# (
# 𝐴
# )
#
# =
# Tr(A)/
# 1−1/2=2
# 	​
#
# Final Answer
# Tr
# (
# 𝐴
# )
# =
# Tr(A)=2
# =

# %%
# Approximating trace using first n diagonal terms
n = 20
trace = sum((1/2)**i for i in range(n))

print("Approximate Trace of A:", trace)
# Out:
# Approximate Trace of A: 1.9999980926513672

# %% [markdown]
# **Time Complexity**
#
# Summing n diagonal terms: O(n)
# Time Complexity: O(n)
#
# **Space Complexity**
#
# Constant extra variables
# Space Complexity: O(1)
